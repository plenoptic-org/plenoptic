# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import pyrtools as pt
import plenoptic as po

# %load_ext autoreload
# %autoreload 2

import torch
import torch.nn as nn
numpy = lambda x : x.detach().cpu().numpy().squeeze()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from plenoptic.simulate.frontend import Front_End
from plenoptic.simulate.steerable_pyramid_freq import Steerable_Pyramid_Freq
from plenoptic.simulate.non_linearities import local_gain_control

# %%
def steer(pyr_coeffs, residuals=True):

    S = np.max(np.array([k for k in pyr_coeffs.keys() if isinstance(k, tuple)])[:, 0]) + 1

    pyr_coeffs_steered = {}

    for s in range(S):
        pyr_coeffs_steered[s, 0] = pyr_coeffs[s, 0]
        pyr_coeffs_steered[s, 1] = (pyr_coeffs[s, 0] + pyr_coeffs[s, 1]) / np.sqrt(2)
        pyr_coeffs_steered[s, 2] = pyr_coeffs[s, 1]
        pyr_coeffs_steered[s, 3] = (pyr_coeffs[s, 1] - pyr_coeffs[s, 0]) / np.sqrt(2)
    

    if residuals:
        pyr_coeffs_steered['residual_lowpass'] = pyr_coeffs['residual_lowpass']
        pyr_coeffs_steered['residual_highpass'] = pyr_coeffs['residual_highpass']

    return pyr_coeffs_steered

# %%
def standardize(X, epsilon=1e-16):
    return (X - torch.mean(X)) / (torch.std(X) + epsilon)

def global_gain_control(coeffs):
    
    coeffs_normalized = {}
    for k in coeffs.keys():
        coeffs_normalized[k] = standardize(coeffs[k])

    return coeffs_normalized

# %%
def ori_diff(coeffs):

    S = np.max(np.array([k for k in coeffs.keys() if isinstance(k, tuple)])[:, 0]) + 1
    B = np.max(np.array([k for k in coeffs.keys() if isinstance(k, tuple)])[:, 1]) + 1
    
    oridiff = {}
    for s in range(S):
        for b in range(B):
            oridiff[s,b] = coeffs[s, (b+1) % 4] - coeffs[s, b]

    return oridiff

# %%
def scale_diff(coeff):
    S = np.max(np.array([k for k in coeff.keys() if isinstance(k, tuple)])[:, 0]) + 1
    B = np.max(np.array([k for k in coeff.keys() if isinstance(k, tuple)])[:, 1]) + 1

    scalediff = {}
    j = 0
    for s in range(1, S):
        for b in range(B):
            fine = coeff[s-1, b] #standardize(coeff[s-1, b])
            coarse = po.upsample_blur(coeff[s, b]) #standardize(po.upsample_blur(coeff[s, b]))
            scalediff[j, b] = (fine - coarse) / np.sqrt(2)
#             scalediff[j+1, b] = (fine + coarse) / np.sqrt(2)
#         j += 2
        j += 1
        
    return scalediff

# %%
class V2(nn.Module):
    """


    """
    def __init__(self, frontend=False, steer=False):
        super(V2, self).__init__()

        self.frontend = frontend
        if self.frontend:
            self.F = Front_End()
            
        self.steer = steer
        if self.steer:
            self.L1 = Steerable_Pyramid_Freq([256, 256], order=1, height=5, is_complex=False)
        else:
            self.L1 = Steerable_Pyramid_Freq([256, 256], order=3, height=5, is_complex=False)
        
        self.L2 = ori_diff
        self.L3 = scale_diff
        
        self.GG = global_gain_control
        self.LG = local_gain_control
        
    def forward(self, x):

        if self.frontend:
            x = self.F(x)
        
        if self.steer:
            self.activation1 = steer(self.L1(x))
        else:
            self.activation1 = self.L1(x)
        
        self.activation_standard = self.GG(self.activation1)
        self.energy1, self.state1 = self.LG(self.activation_standard, (2, 2))

        o = self.GG(self.L2(self.energy1))
        s = self.GG(self.L3(self.energy1))
#         o = self.GG(self.L2(self.state1))
#         s = self.GG(self.L3(self.state1))

        energy2, state2 = self.LG(o, residuals=False)
        energy3, state3 = self.LG(s, residuals=False)

        return [k for k in self.energy1.values()] + [k for k in energy2.values()] + [k for k in energy3.values()]
#         return [k for k in state1.values()] + [k for k in state2.values()] + [k for k in state3.values()]

#         return [k for k in energy2.values()] + [k for k in energy3.values()]

# %%
v2 = V2()

# %%
stimuli = po.make_basic_stimuli()
# pt.imshow(numpy(stimuli));

# %%
y = v2.forward(stimuli)

# %%
v2.activation1[0, 3].shape
# Out:
# torch.Size([15, 1, 256, 256])

# %%
len(y)
# Out:
# 58

# %%
y[0].shape
# Out:
# torch.Size([15, 1, 128, 128])

# %%
[y[i][-3].shape for i in range(len(y))]
# Out:
# [torch.Size([1, 128, 128]),
#  torch.Size([1, 128, 128]),
#  torch.Size([1, 128, 128]),
#  torch.Size([1, 128, 128]),
#  torch.Size([1, 64, 64]),
#  torch.Size([1, 64, 64]),
#  torch.Size([1, 64, 64]),
#  torch.Size([1, 64, 64]),
#  torch.Size([1, 32, 32]),
#  torch.Size([1, 32, 32]),
#  torch.Size([1, 32, 32]),
#  torch.Size([1, 32, 32]),
#  torch.Size([1, 16, 16]),
#  torch.Size([1, 16, 16]),
#  torch.Size([1, 16, 16]),
#  torch.Size([1, 16, 16]),
#  torch.Size([1, 8, 8]),
#  torch.Size([1, 8, 8]),
#  torch.Size([1, 8, 8]),
#  torch.Size([1, 8, 8]),
#  torch.Size([1, 8, 8]),
#  torch.Size([1, 256, 256]),
#  torch.Size([1, 64, 64]),
#  torch.Size([1, 64, 64]),
#  torch.Size([1, 64, 64]),
#  torch.Size([1, 64, 64]),
#  torch.Size([1, 32, 32]),
#  torch.Size([1, 32, 32]),
#  torch.Size([1, 32, 32]),
#  torch.Size([1, 32, 32]),
#  torch.Size([1, 16, 16]),
#  torch.Size([1, 16, 16]),
#  torch.Size([1, 16, 16]),
#  torch.Size([1, 16, 16]),
#  torch.Size([1, 8, 8]),
#  torch.Size([1, 8, 8]),
#  torch.Size([1, 8, 8]),
#  torch.Size([1, 8, 8]),
#  torch.Size([1, 4, 4]),
#  torch.Size([1, 4, 4]),
#  torch.Size([1, 4, 4]),
#  torch.Size([1, 4, 4]),
#  torch.Size([1, 64, 64]),
#  torch.Size([1, 64, 64]),
#  torch.Size([1, 64, 64]),
#  torch.Size([1, 64, 64]),
#  torch.Size([1, 32, 32]),
#  torch.Size([1, 32, 32]),
#  torch.Size([1, 32, 32]),
#  torch.Size([1, 32, 32]),
#  torch.Size([1, 16, 16]),
#  torch.Size([1, 16, 16]),
#  torch.Size([1, 16, 16]),
#  torch.Size([1, 16, 16]),
#  torch.Size([1, 8, 8]),
#  torch.Size([1, 8, 8]),
#  torch.Size([1, 8, 8]),
#  torch.Size([1, 8, 8])]

# %%
m = po.synth.Metamer(stimuli[-3].unsqueeze(0), v2)

# %%
try:
    init = m_im.unsqueeze(0).unsqueeze(0)
except NameError:
    print('init')
    init = None
m_im, m_rep = m.synthesize(initial_image=init, learning_rate=1, save_image=10)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# init
#   0%|          | 0/100 [00:00<?, ?it/s, gradient_norm=3.8632e+00, learning_rate=1, loss=4.3649e+02]
#   1%|          | 1/100 [00:00<00:46,  2.13it/s, gradient_norm=3.8632e+00, learning_rate=1, loss=4.3649e+02]
#   1%|          | 1/100 [00:00<00:46,  2.13it/s, gradient_norm=3.6691e+00, learning_rate=1, loss=4.2201e+02]
#   2%|▏         | 2/100 [00:00<00:46,  2.10it/s, gradient_norm=3.6691e+00, learning_rate=1, loss=4.2201e+02]
#   2%|▏         | 2/100 [00:01<00:46,  2.10it/s, gradient_norm=3.3733e+00, learning_rate=1, loss=3.9945e+02]
#   3%|▎         | 3/100 [00:01<00:45,  2.12it/s, gradient_norm=3.3733e+00, learning_rate=1, loss=3.9945e+02]
#   3%|▎         | 3/100 [00:01<00:45,  2.12it/s, gradient_norm=3.2707e+00, learning_rate=1, loss=3.7460e+02]
#   4%|▍         | 4/100 [00:01<00:46,  2.09it/s, gradient_norm=3.2707e+00, learning_rate=1, loss=3.7460e+02]
#   4%|▍         | 4/100 [00:02<00:46,  2.09it/s, gradient_norm=3.2575e+00, learning_rate=1, loss=3.4825e+02]
#   5%|▌         | 5/100 [00:02<00:46,  2.05it/s, gradient_norm=3.2575e+00, learning_rate=1, loss=3.4825e+02]
#   5%|▌         | 5/100 [00:02<00:46,  2.05it/s, gradient_norm=3.2042e+00, learning_rate=1, loss=3.2026e+02]
#   6%|▌         | 6/100 [00:02<00:46,  2.03it/s, gradient_norm=3.2042e+00, learning_rate=1, loss=3.2026e+02]
#   6%|▌         | 6/100 [00:03<00:46,  2.03it/s, gradient_norm=3.0920e+00, learning_rate=1, loss=2.9144e+02]
#   7%|▋         | 7/100 [00:03<00:45,  2.05it/s, gradient_norm=3.0920e+00, learning_rate=1, loss=2.9144e+02]
#   7%|▋         | 7/100 [00:03<00:45,  2.05it/s, gradient_norm=2.9407e+00, learning_rate=1, loss=2.6304e+02]
#   8%|▊         | 8/100 [00:03<00:45,  2.01it/s, gradient_norm=2.9407e+00, learning_rate=1, loss=2.6304e+02]
#   8%|▊         | 8/100 [00:04<00:45,  2.01it/s, gradient_norm=2.7539e+00, learning_rate=1, loss=2.3626e+02]
#   9%|▉         | 9/100 [00:04<00:45,  2.00it/s, gradient_norm=2.7539e+00, learning_rate=1, loss=2.3626e+02]
#   9%|▉         | 9/100 [00:04<00:45,  2.00it/s, gradient_norm=2.5499e+00, learning_rate=1, loss=2.1205e+02]
#  10%|█         | 10/100 [00:04<00:45,  1.97it/s, gradient_norm=2.5499e+00, learning_rate=1, loss=2.1205e+02]
#  10%|█         | 10/100 [00:05<00:45,  1.97it/s, gradient_norm=2.3344e+00, learning_rate=1, loss=1.9096e+02]
#  11%|█         | 11/100 [00:05<00:45,  1.95it/s, gradient_norm=2.3344e+00, learning_rate=1, loss=1.9096e+02]
#  11%|█         | 11/100 [00:05<00:45,  1.95it/s, gradient_norm=2.0975e+00, learning_rate=1, loss=1.7325e+02]
#  12%|█▏        | 12/100 [00:05<00:44,  1.96it/s, gradient_norm=2.0975e+00, learning_rate=1, loss=1.7325e+02]
#  12%|█▏        | 12/100 [00:06<00:44,  1.96it/s, gradient_norm=1.8806e+00, learning_rate=1, loss=1.5903e+02]
#  13%|█▎        | 13/100 [00:06<00:43,  1.99it/s, gradient_norm=1.8806e+00, learning_rate=1, loss=1.5903e+02]
#  13%|█▎        | 13/100 [00:06<00:43,  1.99it/s, gradient_norm=1.6999e+00, learning_rate=1, loss=1.4796e+02]
#  14%|█▍        | 14/100 [00:06<00:42,  2.00it/s, gradient_norm=1.6999e+00, learning_rate=1, loss=1.4796e+02]
#  14%|█▍        | 14/100 [00:07<00:42,  2.00it/s, gradient_norm=1.5243e+00, learning_rate=1, loss=1.3948e+02]
#  15%|█▌        | 15/100 [00:07<00:42,  2.02it/s, gradient_norm=1.5243e+00, learning_rate=1, loss=1.3948e+02]
#  15%|█▌        | 15/100 [00:07<00:42,  2.02it/s, gradient_norm=1.3849e+00, learning_rate=1, loss=1.3309e+02]
#  16%|█▌        | 16/100 [00:07<00:41,  2.01it/s, gradient_norm=1.3849e+00, learning_rate=1, loss=1.3309e+02]
#  16%|█▌        | 16/100 [00:08<00:41,  2.01it/s, gradient_norm=1.2837e+00, learning_rate=1, loss=1.2825e+02]
#  17%|█▋        | 17/100 [00:08<00:41,  2.01it/s, gradient_norm=1.2837e+00, learning_rate=1, loss=1.2825e+02]
#  17%|█▋        | 17/100 [00:08<00:41,  2.01it/s, gradient_norm=1.2081e+00, learning_rate=1, loss=1.2441e+02]
#  18%|█▊        | 18/100 [00:08<00:41,  1.99it/s, gradient_norm=1.2081e+00, learning_rate=1, loss=1.2441e+02]
#  18%|█▊        | 18/100 [00:09<00:41,  1.99it/s, gradient_norm=1.1409e+00, learning_rate=1, loss=1.2119e+02]
#  19%|█▉        | 19/100 [00:09<00:39,  2.03it/s, gradient_norm=1.1409e+00, learning_rate=1, loss=1.2119e+02]
#  19%|█▉        | 19/100 [00:09<00:39,  2.03it/s, gradient_norm=1.0845e+00, learning_rate=1, loss=1.1830e+02]
#  20%|██        | 20/100 [00:09<00:39,  2.03it/s, gradient_norm=1.0845e+00, learning_rate=1, loss=1.1830e+02]
#  20%|██        | 20/100 [00:10<00:39,  2.03it/s, gradient_norm=1.0354e+00, learning_rate=1, loss=1.1560e+02]
#  21%|██        | 21/100 [00:10<00:38,  2.04it/s, gradient_norm=1.0354e+00, learning_rate=1, loss=1.1560e+02]
#  21%|██        | 21/100 [00:10<00:38,  2.04it/s, gradient_norm=9.8847e-01, learning_rate=1, loss=1.1298e+02]
#  22%|██▏       | 22/100 [00:10<00:38,  2.05it/s, gradient_norm=9.8847e-01, learning_rate=1, loss=1.1298e+02]
#  22%|██▏       | 22/100 [00:11<00:38,  2.05it/s, gradient_norm=9.3800e-01, learning_rate=1, loss=1.1041e+02]
#  23%|██▎       | 23/100 [00:11<00:37,  2.04it/s, gradient_norm=9.3800e-01, learning_rate=1, loss=1.1041e+02]
#  23%|██▎       | 23/100 [00:11<00:37,  2.04it/s, gradient_norm=8.9291e-01, learning_rate=1, loss=1.0790e+02]
#  24%|██▍       | 24/100 [00:11<00:37,  2.05it/s, gradient_norm=8.9291e-01, learning_rate=1, loss=1.0790e+02]
#  24%|██▍       | 24/100 [00:12<00:37,  2.05it/s, gradient_norm=8.4434e-01, learning_rate=1, loss=1.0547e+02]
#  25%|██▌       | 25/100 [00:12<00:36,  2.04it/s, gradient_norm=8.4434e-01, learning_rate=1, loss=1.0547e+02]
#  25%|██▌       | 25/100 [00:12<00:36,  2.04it/s, gradient_norm=7.9253e-01, learning_rate=1, loss=1.0315e+02]
#  26%|██▌       | 26/100 [00:12<00:36,  2.04it/s, gradient_norm=7.9253e-01, learning_rate=1, loss=1.0315e+02]
#  26%|██▌       | 26/100 [00:13<00:36,  2.04it/s, gradient_norm=7.4169e-01, learning_rate=1, loss=1.0097e+02]
#  27%|██▋       | 27/100 [00:13<00:35,  2.03it/s, gradient_norm=7.4169e-01, learning_rate=1, loss=1.0097e+02]
#  27%|██▋       | 27/100 [00:13<00:35,  2.03it/s, gradient_norm=6.9561e-01, learning_rate=1, loss=9.8960e+01]
#  28%|██▊       | 28/100 [00:13<00:35,  2.02it/s, gradient_norm=6.9561e-01, learning_rate=1, loss=9.8960e+01]
#  28%|██▊       | 28/100 [00:14<00:35,  2.02it/s, gradient_norm=6.5847e-01, learning_rate=1, loss=9.7122e+01]
#  29%|██▉       | 29/100 [00:14<00:35,  2.01it/s, gradient_norm=6.5847e-01, learning_rate=1, loss=9.7122e+01]
#  29%|██▉       | 29/100 [00:14<00:35,  2.01it/s, gradient_norm=6.2766e-01, learning_rate=1, loss=9.5442e+01]
#  30%|███       | 30/100 [00:14<00:35,  1.99it/s, gradient_norm=6.2766e-01, learning_rate=1, loss=9.5442e+01]
#  30%|███       | 30/100 [00:15<00:35,  1.99it/s, gradient_norm=6.0055e-01, learning_rate=1, loss=9.3897e+01]
#  31%|███       | 31/100 [00:15<00:35,  1.97it/s, gradient_norm=6.0055e-01, learning_rate=1, loss=9.3897e+01]
#  31%|███       | 31/100 [00:15<00:35,  1.97it/s, gradient_norm=5.8055e-01, learning_rate=1, loss=9.2466e+01]
#  32%|███▏      | 32/100 [00:15<00:34,  1.97it/s, gradient_norm=5.8055e-01, learning_rate=1, loss=9.2466e+01]
#  32%|███▏      | 32/100 [00:16<00:34,  1.97it/s, gradient_norm=5.6601e-01, learning_rate=1, loss=9.1123e+01]
#  33%|███▎      | 33/100 [00:16<00:33,  1.97it/s, gradient_norm=5.6601e-01, learning_rate=1, loss=9.1123e+01]
#  33%|███▎      | 33/100 [00:16<00:33,  1.97it/s, gradient_norm=5.5207e-01, learning_rate=1, loss=8.9844e+01]
#  34%|███▍      | 34/100 [00:16<00:33,  1.99it/s, gradient_norm=5.5207e-01, learning_rate=1, loss=8.9844e+01]
#  34%|███▍      | 34/100 [00:17<00:33,  1.99it/s, gradient_norm=5.3888e-01, learning_rate=1, loss=8.8614e+01]
#  35%|███▌      | 35/100 [00:17<00:32,  1.99it/s, gradient_norm=5.3888e-01, learning_rate=1, loss=8.8614e+01]
#  35%|███▌      | 35/100 [00:17<00:32,  1.99it/s, gradient_norm=5.2624e-01, learning_rate=1, loss=8.7424e+01]
#  36%|███▌      | 36/100 [00:17<00:31,  2.01it/s, gradient_norm=5.2624e-01, learning_rate=1, loss=8.7424e+01]
#  36%|███▌      | 36/100 [00:18<00:31,  2.01it/s, gradient_norm=5.1318e-01, learning_rate=1, loss=8.6271e+01]
#  37%|███▋      | 37/100 [00:18<00:31,  2.03it/s, gradient_norm=5.1318e-01, learning_rate=1, loss=8.6271e+01]
#  37%|███▋      | 37/100 [00:18<00:31,  2.03it/s, gradient_norm=4.9954e-01, learning_rate=1, loss=8.5154e+01]
#  38%|███▊      | 38/100 [00:18<00:30,  2.04it/s, gradient_norm=4.9954e-01, learning_rate=1, loss=8.5154e+01]
#  38%|███▊      | 38/100 [00:19<00:30,  2.04it/s, gradient_norm=4.8622e-01, learning_rate=1, loss=8.4075e+01]
#  39%|███▉      | 39/100 [00:19<00:29,  2.06it/s, gradient_norm=4.8622e-01, learning_rate=1, loss=8.4075e+01]
#  39%|███▉      | 39/100 [00:19<00:29,  2.06it/s, gradient_norm=4.7381e-01, learning_rate=1, loss=8.3035e+01]
#  40%|████      | 40/100 [00:19<00:29,  2.04it/s, gradient_norm=4.7381e-01, learning_rate=1, loss=8.3035e+01]
#  40%|████      | 40/100 [00:20<00:29,  2.04it/s, gradient_norm=4.6245e-01, learning_rate=1, loss=8.2034e+01]
#  41%|████      | 41/100 [00:20<00:28,  2.07it/s, gradient_norm=4.6245e-01, learning_rate=1, loss=8.2034e+01]
#  41%|████      | 41/100 [00:20<00:28,  2.07it/s, gradient_norm=4.5244e-01, learning_rate=1, loss=8.1071e+01]
#  42%|████▏     | 42/100 [00:20<00:27,  2.08it/s, gradient_norm=4.5244e-01, learning_rate=1, loss=8.1071e+01]
#  42%|████▏     | 42/100 [00:21<00:27,  2.08it/s, gradient_norm=4.4375e-01, learning_rate=1, loss=8.0143e+01]
#  43%|████▎     | 43/100 [00:21<00:28,  2.03it/s, gradient_norm=4.4375e-01, learning_rate=1, loss=8.0143e+01]
#  43%|████▎     | 43/100 [00:21<00:28,  2.03it/s, gradient_norm=4.3619e-01, learning_rate=1, loss=7.9247e+01]
#  44%|████▍     | 44/100 [00:21<00:28,  2.00it/s, gradient_norm=4.3619e-01, learning_rate=1, loss=7.9247e+01]
#  44%|████▍     | 44/100 [00:22<00:28,  2.00it/s, gradient_norm=4.2929e-01, learning_rate=1, loss=7.8379e+01]
#  45%|████▌     | 45/100 [00:22<00:27,  2.00it/s, gradient_norm=4.2929e-01, learning_rate=1, loss=7.8379e+01]
#  45%|████▌     | 45/100 [00:22<00:27,  2.00it/s, gradient_norm=4.2284e-01, learning_rate=1, loss=7.7535e+01]
#  46%|████▌     | 46/100 [00:22<00:26,  2.01it/s, gradient_norm=4.2284e-01, learning_rate=1, loss=7.7535e+01]
#  46%|████▌     | 46/100 [00:23<00:26,  2.01it/s, gradient_norm=4.1677e-01, learning_rate=1, loss=7.6715e+01]
#  47%|████▋     | 47/100 [00:23<00:25,  2.04it/s, gradient_norm=4.1677e-01, learning_rate=1, loss=7.6715e+01]
#  47%|████▋     | 47/100 [00:23<00:25,  2.04it/s, gradient_norm=4.1087e-01, learning_rate=1, loss=7.5915e+01]
#  48%|████▊     | 48/100 [00:23<00:25,  2.04it/s, gradient_norm=4.1087e-01, learning_rate=1, loss=7.5915e+01]
#  48%|████▊     | 48/100 [00:24<00:25,  2.04it/s, gradient_norm=4.0513e-01, learning_rate=1, loss=7.5134e+01]
#  49%|████▉     | 49/100 [00:24<00:24,  2.05it/s, gradient_norm=4.0513e-01, learning_rate=1, loss=7.5134e+01]
#  49%|████▉     | 49/100 [00:24<00:24,  2.05it/s, gradient_norm=3.9958e-01, learning_rate=1, loss=7.4372e+01]
#  50%|█████     | 50/100 [00:24<00:24,  2.04it/s, gradient_norm=3.9958e-01, learning_rate=1, loss=7.4372e+01]
#  50%|█████     | 50/100 [00:25<00:24,  2.04it/s, gradient_norm=3.9423e-01, learning_rate=1, loss=7.3628e+01]
#  51%|█████     | 51/100 [00:25<00:23,  2.06it/s, gradient_norm=3.9423e-01, learning_rate=1, loss=7.3628e+01]
#  51%|█████     | 51/100 [00:25<00:23,  2.06it/s, gradient_norm=3.8910e-01, learning_rate=1, loss=7.2902e+01]
#  52%|█████▏    | 52/100 [00:25<00:23,  2.04it/s, gradient_norm=3.8910e-01, learning_rate=1, loss=7.2902e+01]
#  52%|█████▏    | 52/100 [00:26<00:23,  2.04it/s, gradient_norm=3.8417e-01, learning_rate=1, loss=7.2193e+01]
#  53%|█████▎    | 53/100 [00:26<00:23,  2.03it/s, gradient_norm=3.8417e-01, learning_rate=1, loss=7.2193e+01]
#  53%|█████▎    | 53/100 [00:26<00:23,  2.03it/s, gradient_norm=3.7940e-01, learning_rate=1, loss=7.1500e+01]
#  54%|█████▍    | 54/100 [00:26<00:22,  2.02it/s, gradient_norm=3.7940e-01, learning_rate=1, loss=7.1500e+01]
#  54%|█████▍    | 54/100 [00:27<00:22,  2.02it/s, gradient_norm=3.7475e-01, learning_rate=1, loss=7.0823e+01]
#  55%|█████▌    | 55/100 [00:27<00:22,  2.03it/s, gradient_norm=3.7475e-01, learning_rate=1, loss=7.0823e+01]
#  55%|█████▌    | 55/100 [00:27<00:22,  2.03it/s, gradient_norm=3.7009e-01, learning_rate=1, loss=7.0162e+01]
#  56%|█████▌    | 56/100 [00:27<00:21,  2.02it/s, gradient_norm=3.7009e-01, learning_rate=1, loss=7.0162e+01]
#  56%|█████▌    | 56/100 [00:28<00:21,  2.02it/s, gradient_norm=3.6537e-01, learning_rate=1, loss=6.9517e+01]
#  57%|█████▋    | 57/100 [00:28<00:21,  2.00it/s, gradient_norm=3.6537e-01, learning_rate=1, loss=6.9517e+01]
#  57%|█████▋    | 57/100 [00:28<00:21,  2.00it/s, gradient_norm=3.6056e-01, learning_rate=1, loss=6.8887e+01]
#  58%|█████▊    | 58/100 [00:28<00:21,  1.98it/s, gradient_norm=3.6056e-01, learning_rate=1, loss=6.8887e+01]
#  58%|█████▊    | 58/100 [00:29<00:21,  1.98it/s, gradient_norm=3.5572e-01, learning_rate=1, loss=6.8274e+01]
#  59%|█████▉    | 59/100 [00:29<00:20,  2.02it/s, gradient_norm=3.5572e-01, learning_rate=1, loss=6.8274e+01]
#  59%|█████▉    | 59/100 [00:29<00:20,  2.02it/s, gradient_norm=3.5095e-01, learning_rate=1, loss=6.7676e+01]
#  60%|██████    | 60/100 [00:29<00:20,  1.99it/s, gradient_norm=3.5095e-01, learning_rate=1, loss=6.7676e+01]
#  60%|██████    | 60/100 [00:30<00:20,  1.99it/s, gradient_norm=3.4633e-01, learning_rate=1, loss=6.7093e+01]
#  61%|██████    | 61/100 [00:30<00:19,  2.00it/s, gradient_norm=3.4633e-01, learning_rate=1, loss=6.7093e+01]
#  61%|██████    | 61/100 [00:30<00:19,  2.00it/s, gradient_norm=3.4191e-01, learning_rate=1, loss=6.6526e+01]
#  62%|██████▏   | 62/100 [00:30<00:19,  2.00it/s, gradient_norm=3.4191e-01, learning_rate=1, loss=6.6526e+01]
#  62%|██████▏   | 62/100 [00:31<00:19,  2.00it/s, gradient_norm=3.3769e-01, learning_rate=1, loss=6.5972e+01]
#  63%|██████▎   | 63/100 [00:31<00:18,  2.01it/s, gradient_norm=3.3769e-01, learning_rate=1, loss=6.5972e+01]
#  63%|██████▎   | 63/100 [00:31<00:18,  2.01it/s, gradient_norm=3.3365e-01, learning_rate=1, loss=6.5433e+01]
#  64%|██████▍   | 64/100 [00:31<00:18,  2.00it/s, gradient_norm=3.3365e-01, learning_rate=1, loss=6.5433e+01]
#  64%|██████▍   | 64/100 [00:32<00:18,  2.00it/s, gradient_norm=3.2976e-01, learning_rate=1, loss=6.4906e+01]
#  65%|██████▌   | 65/100 [00:32<00:17,  2.01it/s, gradient_norm=3.2976e-01, learning_rate=1, loss=6.4906e+01]
#  65%|██████▌   | 65/100 [00:32<00:17,  2.01it/s, gradient_norm=3.2599e-01, learning_rate=1, loss=6.4391e+01]
#  66%|██████▌   | 66/100 [00:32<00:16,  2.01it/s, gradient_norm=3.2599e-01, learning_rate=1, loss=6.4391e+01]
#  66%|██████▌   | 66/100 [00:33<00:16,  2.01it/s, gradient_norm=3.2231e-01, learning_rate=1, loss=6.3887e+01]
#  67%|██████▋   | 67/100 [00:33<00:16,  2.04it/s, gradient_norm=3.2231e-01, learning_rate=1, loss=6.3887e+01]
#  67%|██████▋   | 67/100 [00:33<00:16,  2.04it/s, gradient_norm=3.1867e-01, learning_rate=1, loss=6.3395e+01]
#  68%|██████▊   | 68/100 [00:33<00:15,  2.06it/s, gradient_norm=3.1867e-01, learning_rate=1, loss=6.3395e+01]
#  68%|██████▊   | 68/100 [00:34<00:15,  2.06it/s, gradient_norm=3.1502e-01, learning_rate=1, loss=6.2913e+01]
#  69%|██████▉   | 69/100 [00:34<00:15,  2.06it/s, gradient_norm=3.1502e-01, learning_rate=1, loss=6.2913e+01]
#  69%|██████▉   | 69/100 [00:34<00:15,  2.06it/s, gradient_norm=3.1135e-01, learning_rate=1, loss=6.2441e+01]
#  70%|███████   | 70/100 [00:34<00:14,  2.02it/s, gradient_norm=3.1135e-01, learning_rate=1, loss=6.2441e+01]
#  70%|███████   | 70/100 [00:35<00:14,  2.02it/s, gradient_norm=3.0768e-01, learning_rate=1, loss=6.1981e+01]
#  71%|███████   | 71/100 [00:35<00:15,  1.89it/s, gradient_norm=3.0768e-01, learning_rate=1, loss=6.1981e+01]
#  71%|███████   | 71/100 [00:35<00:15,  1.89it/s, gradient_norm=3.0403e-01, learning_rate=1, loss=6.1530e+01]
#  72%|███████▏  | 72/100 [00:35<00:14,  1.90it/s, gradient_norm=3.0403e-01, learning_rate=1, loss=6.1530e+01]
#  72%|███████▏  | 72/100 [00:36<00:14,  1.90it/s, gradient_norm=3.0045e-01, learning_rate=1, loss=6.1090e+01]
#  73%|███████▎  | 73/100 [00:36<00:14,  1.93it/s, gradient_norm=3.0045e-01, learning_rate=1, loss=6.1090e+01]
#  73%|███████▎  | 73/100 [00:36<00:14,  1.93it/s, gradient_norm=2.9697e-01, learning_rate=1, loss=6.0660e+01]
#  74%|███████▍  | 74/100 [00:36<00:13,  1.95it/s, gradient_norm=2.9697e-01, learning_rate=1, loss=6.0660e+01]
#  74%|███████▍  | 74/100 [00:37<00:13,  1.95it/s, gradient_norm=2.9358e-01, learning_rate=1, loss=6.0239e+01]
#  75%|███████▌  | 75/100 [00:37<00:12,  1.99it/s, gradient_norm=2.9358e-01, learning_rate=1, loss=6.0239e+01]
#  75%|███████▌  | 75/100 [00:37<00:12,  1.99it/s, gradient_norm=2.9024e-01, learning_rate=1, loss=5.9828e+01]
#  76%|███████▌  | 76/100 [00:37<00:11,  2.01it/s, gradient_norm=2.9024e-01, learning_rate=1, loss=5.9828e+01]
#  76%|███████▌  | 76/100 [00:38<00:11,  2.01it/s, gradient_norm=2.8691e-01, learning_rate=1, loss=5.9426e+01]
#  77%|███████▋  | 77/100 [00:38<00:11,  2.04it/s, gradient_norm=2.8691e-01, learning_rate=1, loss=5.9426e+01]
#  77%|███████▋  | 77/100 [00:38<00:11,  2.04it/s, gradient_norm=2.8357e-01, learning_rate=1, loss=5.9033e+01]
#  78%|███████▊  | 78/100 [00:38<00:10,  2.03it/s, gradient_norm=2.8357e-01, learning_rate=1, loss=5.9033e+01]
#  78%|███████▊  | 78/100 [00:39<00:10,  2.03it/s, gradient_norm=2.8023e-01, learning_rate=1, loss=5.8649e+01]
#  79%|███████▉  | 79/100 [00:39<00:10,  2.06it/s, gradient_norm=2.8023e-01, learning_rate=1, loss=5.8649e+01]
#  79%|███████▉  | 79/100 [00:39<00:10,  2.06it/s, gradient_norm=2.7692e-01, learning_rate=1, loss=5.8274e+01]
#  80%|████████  | 80/100 [00:39<00:09,  2.08it/s, gradient_norm=2.7692e-01, learning_rate=1, loss=5.8274e+01]
#  80%|████████  | 80/100 [00:40<00:09,  2.08it/s, gradient_norm=2.7368e-01, learning_rate=1, loss=5.7907e+01]
#  81%|████████  | 81/100 [00:40<00:09,  2.08it/s, gradient_norm=2.7368e-01, learning_rate=1, loss=5.7907e+01]
#  81%|████████  | 81/100 [00:40<00:09,  2.08it/s, gradient_norm=2.7050e-01, learning_rate=1, loss=5.7548e+01]
#  82%|████████▏ | 82/100 [00:40<00:08,  2.09it/s, gradient_norm=2.7050e-01, learning_rate=1, loss=5.7548e+01]
#  82%|████████▏ | 82/100 [00:41<00:08,  2.09it/s, gradient_norm=2.6736e-01, learning_rate=1, loss=5.7198e+01]
#  83%|████████▎ | 83/100 [00:41<00:08,  2.07it/s, gradient_norm=2.6736e-01, learning_rate=1, loss=5.7198e+01]
#  83%|████████▎ | 83/100 [00:41<00:08,  2.07it/s, gradient_norm=2.6422e-01, learning_rate=1, loss=5.6855e+01]
#  84%|████████▍ | 84/100 [00:41<00:07,  2.08it/s, gradient_norm=2.6422e-01, learning_rate=1, loss=5.6855e+01]
#  84%|████████▍ | 84/100 [00:42<00:07,  2.08it/s, gradient_norm=2.6104e-01, learning_rate=1, loss=5.6520e+01]
#  85%|████████▌ | 85/100 [00:42<00:07,  2.08it/s, gradient_norm=2.6104e-01, learning_rate=1, loss=5.6520e+01]
#  85%|████████▌ | 85/100 [00:42<00:07,  2.08it/s, gradient_norm=2.5784e-01, learning_rate=1, loss=5.6192e+01]
#  86%|████████▌ | 86/100 [00:42<00:06,  2.10it/s, gradient_norm=2.5784e-01, learning_rate=1, loss=5.6192e+01]
#  86%|████████▌ | 86/100 [00:43<00:06,  2.10it/s, gradient_norm=2.5464e-01, learning_rate=1, loss=5.5872e+01]
#  87%|████████▋ | 87/100 [00:43<00:06,  2.05it/s, gradient_norm=2.5464e-01, learning_rate=1, loss=5.5872e+01]
#  87%|████████▋ | 87/100 [00:43<00:06,  2.05it/s, gradient_norm=2.5150e-01, learning_rate=1, loss=5.5559e+01]
#  88%|████████▊ | 88/100 [00:43<00:05,  2.05it/s, gradient_norm=2.5150e-01, learning_rate=1, loss=5.5559e+01]
#  88%|████████▊ | 88/100 [00:44<00:05,  2.05it/s, gradient_norm=2.4849e-01, learning_rate=1, loss=5.5254e+01]
#  89%|████████▉ | 89/100 [00:44<00:05,  2.05it/s, gradient_norm=2.4849e-01, learning_rate=1, loss=5.5254e+01]
#  89%|████████▉ | 89/100 [00:44<00:05,  2.05it/s, gradient_norm=2.4565e-01, learning_rate=1, loss=5.4955e+01]
#  90%|█████████ | 90/100 [00:44<00:04,  2.05it/s, gradient_norm=2.4565e-01, learning_rate=1, loss=5.4955e+01]
#  90%|█████████ | 90/100 [00:45<00:04,  2.05it/s, gradient_norm=2.4302e-01, learning_rate=1, loss=5.4664e+01]
#  91%|█████████ | 91/100 [00:45<00:04,  1.99it/s, gradient_norm=2.4302e-01, learning_rate=1, loss=5.4664e+01]
#  91%|█████████ | 91/100 [00:45<00:04,  1.99it/s, gradient_norm=2.4058e-01, learning_rate=1, loss=5.4378e+01]
#  92%|█████████▏| 92/100 [00:45<00:04,  1.96it/s, gradient_norm=2.4058e-01, learning_rate=1, loss=5.4378e+01]
#  92%|█████████▏| 92/100 [00:46<00:04,  1.96it/s, gradient_norm=2.3833e-01, learning_rate=1, loss=5.4098e+01]
#  93%|█████████▎| 93/100 [00:46<00:03,  1.97it/s, gradient_norm=2.3833e-01, learning_rate=1, loss=5.4098e+01]
#  93%|█████████▎| 93/100 [00:46<00:03,  1.97it/s, gradient_norm=2.3622e-01, learning_rate=1, loss=5.3824e+01]
#  94%|█████████▍| 94/100 [00:46<00:03,  2.00it/s, gradient_norm=2.3622e-01, learning_rate=1, loss=5.3824e+01]
#  94%|█████████▍| 94/100 [00:47<00:03,  2.00it/s, gradient_norm=2.3426e-01, learning_rate=1, loss=5.3555e+01]
#  95%|█████████▌| 95/100 [00:47<00:02,  1.99it/s, gradient_norm=2.3426e-01, learning_rate=1, loss=5.3555e+01]
#  95%|█████████▌| 95/100 [00:47<00:02,  1.99it/s, gradient_norm=2.3246e-01, learning_rate=1, loss=5.3291e+01]
#  96%|█████████▌| 96/100 [00:47<00:02,  1.97it/s, gradient_norm=2.3246e-01, learning_rate=1, loss=5.3291e+01]
#  96%|█████████▌| 96/100 [00:48<00:02,  1.97it/s, gradient_norm=2.3089e-01, learning_rate=1, loss=5.3031e+01]
#  97%|█████████▋| 97/100 [00:48<00:01,  2.00it/s, gradient_norm=2.3089e-01, learning_rate=1, loss=5.3031e+01]
#  97%|█████████▋| 97/100 [00:48<00:01,  2.00it/s, gradient_norm=2.2955e-01, learning_rate=1, loss=5.2775e+01]
#  98%|█████████▊| 98/100 [00:48<00:00,  2.01it/s, gradient_norm=2.2955e-01, learning_rate=1, loss=5.2775e+01]
#  98%|█████████▊| 98/100 [00:49<00:00,  2.01it/s, gradient_norm=2.2843e-01, learning_rate=1, loss=5.2522e+01]
#  99%|█████████▉| 99/100 [00:49<00:00,  2.02it/s, gradient_norm=2.2843e-01, learning_rate=1, loss=5.2522e+01]
#  99%|█████████▉| 99/100 [00:49<00:00,  2.02it/s, gradient_norm=2.2738e-01, learning_rate=1, loss=5.2272e+01]
# 100%|██████████| 100/100 [00:49<00:00,  2.00it/s, gradient_norm=2.2738e-01, learning_rate=1, loss=5.2272e+01]

# %%
plt.plot(m.loss)

# %%
pt.imshow([numpy(m.target_image), numpy(m.matched_image)]);
# Out:
# <PyrFigure size 522x320 with 2 Axes>

# %%
# animation
# pt.animshow(numpy(m.saved_image))

# %%
plt.semilogy(numpy(m.target_representation));

# %%
plt.semilogy(numpy(m.matched_representation));

# %%
spatial_channel_local_blurr = nn.Conv3d(1, 1, (7, 5, 5), stride=(2,2,2))

# %%
k = (3, 5, 5)
p = (1, 2, 2)
m = nn.AvgPool3d(kernel_size=k, stride=(1,1,1), padding=p, count_include_pad=False)

# %%
s = 0
a = torch.cat([v2.energy1[s, b] for b in range(4)], dim=1)

# %%
epsilon = 1e-12
denom = m( a.unsqueeze(1) ** 2) ** .5
b = a / (denom.squeeze(1) ) # max(meandenom, denom)

# %%
# Local Contrast Normalization 2009
# What is the Best Multi-Stage Architecture for Object Recognition
# Jarrett
# mean substract
# stabilize division using a max

# Local Response Normalization
# ImageNet Classification with Deep ConvolutionalNeural Networks
# Krizhevsky
# no mean sub (lateral inhibition)
# divide by (1 + 1e-4 * sum sq)**.75

# generalized divisive normalization
# Balle
# y[i] = x[i] / sqrt(beta[i] + sum_j(gamma[j, i] * x[j]))
# https://github.com/jorge-pessoa/pytorch-gdn/blob/master/pytorch_gdn/__init__.py

# %%
plt.hist(numpy(denom).flatten());

# %%
b.shape
# Out:
# torch.Size([15, 4, 128, 128])

# %%
# space orientation gain control

energy = {}
state = {}

for key in coeff_dict.keys():
    if isinstance(key, tuple):
        energy[key], state[key] = ...(coeff_dict[key], step=step)

if residuals:
    energy['residual_lowpass'] = coeff_dict['residual_lowpass']
    energy['residual_highpass'] = coeff_dict['residual_highpass']

    return energy, state
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-936ddd773af0> in <module>
#       4 state = {}
#       5
# ----> 6 for key in coeff_dict.keys():
#       7     if isinstance(key, tuple):
#       8         energy[key], state[key] = ...(coeff_dict[key], step=step)
#
# NameError: name 'coeff_dict' is not defined

# %%
t = torch.cat([po.blur_downsample(v2.activation1[0, b]) for b in range(4)], dim=1).unsqueeze(1)

# %%
f = torch.tensor(pt.named_filter('binom5').squeeze())

# %%
filt = torch.einsum('i, j, k -> ijk', (f, f, f))

# %%
torch.roll(f)
# Out:
# tensor([0.0884, 0.0884, 0.3536, 0.5303, 0.3536], dtype=torch.float64)

# %%
#channel whitening

# %%
v2.activation1[0, 0].shape
# Out:
# torch.Size([15, 1, 256, 256])

# %%
G = []
for s in range(4):

    a = torch.cat([v2.energy1[s, b][-1].unsqueeze(0) for b in range(4)], dim=1)
    N = a.shape[-1] * a.shape[-2]
    g = torch.einsum('bchw, bdhw -> bcd', (a,a)) / N
    print(torch.symeig(g[0], eigenvectors=True))
    G.append(g)

G = torch.cat(G)
# Out:
# torch.return_types.symeig(
# eigenvalues=tensor([0.0564, 0.2641, 0.3553, 7.3157], grad_fn=<SymeigBackward>),
# eigenvectors=tensor([[ 0.5456, -0.4773, -0.4718,  0.5020],
#         [-0.5194, -0.5190,  0.4577,  0.5013],
#         [ 0.4519,  0.5056,  0.5408,  0.4978],
#         [-0.4778,  0.4973, -0.5249,  0.4989]], grad_fn=<SymeigBackward>))
# torch.return_types.symeig(
# eigenvalues=tensor([0.0562, 0.1431, 0.2080, 7.5842], grad_fn=<SymeigBackward>),
# eigenvectors=tensor([[-0.5985, -0.3441,  0.5219,  0.5011],
#         [ 0.5337, -0.6201, -0.2794,  0.5026],
#         [-0.3910,  0.3721, -0.6798,  0.4965],
#         [ 0.4518,  0.5988,  0.4330,  0.4998]], grad_fn=<SymeigBackward>))
# torch.return_types.symeig(
# eigenvalues=tensor([0.0505, 0.0780, 0.1267, 7.7353], grad_fn=<SymeigBackward>),
# eigenvectors=tensor([[-0.7487,  0.0518, -0.4295,  0.5022],
#         [ 0.4010,  0.7656, -0.0189,  0.5027],
#         [-0.1572, -0.2220,  0.8255,  0.4945],
#         [ 0.5039, -0.6015, -0.3656,  0.5006]], grad_fn=<SymeigBackward>))
# torch.return_types.symeig(
# eigenvalues=tensor([0.0401, 0.1225, 0.4191, 7.4317], grad_fn=<SymeigBackward>),
# eigenvectors=tensor([[ 0.3870,  0.0042,  0.7864,  0.4815],
#         [-0.4002, -0.7531, -0.1114,  0.5102],
#         [ 0.6096,  0.1043, -0.6065,  0.4997],
#         [-0.5643,  0.6496, -0.0369,  0.5081]], grad_fn=<SymeigBackward>))
